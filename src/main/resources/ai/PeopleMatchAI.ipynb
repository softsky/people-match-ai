# %% [markdown]
# # Code TensorFlow Wide & Deep TF.Learn API

# %%
# !pip install pandas tensorflow argparse --user
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python2.7/dist-packages
# Requirement already satisfied: tensorflow in /usr/local/lib/python2.7/dist-packages
# Requirement already satisfied: argparse in /usr/lib/python2.7
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python2.7/dist-packages (from pandas)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python2.7/dist-packages (from pandas)
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python2.7/dist-packages (from pandas)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow)
# Requirement already satisfied: protobuf>=3.1.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow)
# Requirement already satisfied: wheel in /usr/local/lib/python2.7/dist-packages (from tensorflow)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow)
# Requirement already satisfied: setuptools in /usr/local/lib/python2.7/dist-packages (from protobuf>=3.1.0->tensorflow)
# Requirement already satisfied: funcsigs>=1; python_version < "3.3" in /usr/local/lib/python2.7/dist-packages (from mock>=2.0.0->tensorflow)
# Requirement already satisfied: pbr>=0.11 in /usr/local/lib/python2.7/dist-packages (from mock>=2.0.0->tensorflow)
# Requirement already satisfied: appdirs>=1.4.0 in /usr/local/lib/python2.7/dist-packages (from setuptools->protobuf>=3.1.0->tensorflow)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python2.7/dist-packages (from setuptools->protobuf>=3.1.0->tensorflow)
# Requirement already satisfied: pyparsing in /usr/local/lib/python2.7/dist-packages (from packaging>=16.8->setuptools->protobuf>=3.1.0->tensorflow)

# %% [markdown]
# ### Importing required libraries

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import sys
import tempfile

from six.moves import urllib

import pandas as pd
import tensorflow as tf

# %% [markdown]
# ### Preserving warning output

# %%
tf.logging.set_verbosity(tf.logging.ERROR)

# %% [markdown]
# ### Column Initialization

# %%
COLUMNS = ["age", "workclass", "fnlwgt", "education", "education_num",
           "marital_status", "occupation", "relationship", "race", "gender",
           "capital_gain", "capital_loss", "hours_per_week", "native_country",
           "income_bracket"]
LABEL_COLUMN = "label"
CATEGORICAL_COLUMNS = ["workclass", "education", "marital_status", "occupation",
                       "relationship", "race", "gender", "native_country"]
CONTINUOUS_COLUMNS = ["age", "education_num", "capital_gain", "capital_loss",
                      "hours_per_week"]

# %% [markdown]
# ### Determine train and test data file names

# %%
def get_train_data_files(train_data, test_data):
  """Maybe downloads training data and returns train and test file names."""
  if train_data:
    train_file_name = train_data
  else:
    train_file_name = "train_data.csv"
    print("Training data is used from %s" % train_file_name)

  if test_data:
    test_file_name = test_data
  else:
    test_file_name = "test_data.csv"
    print("Test data is used from %s" % test_file_name)

  return train_file_name, test_file_name

# %% [markdown]
# ### Building custom-purpose Neural Network

# %%
def build_estimator(model_dir, model_type):
  """Build an estimator."""
  # Sparse base columns.
  gender = tf.contrib.layers.sparse_column_with_keys(column_name="gender",
                                                     keys=["female", "male"])
  education = tf.contrib.layers.sparse_column_with_hash_bucket(
      "education", hash_bucket_size=1000)
  relationship = tf.contrib.layers.sparse_column_with_hash_bucket(
      "relationship", hash_bucket_size=100)
  workclass = tf.contrib.layers.sparse_column_with_hash_bucket(
      "workclass", hash_bucket_size=100)
  occupation = tf.contrib.layers.sparse_column_with_hash_bucket(
      "occupation", hash_bucket_size=1000)
  native_country = tf.contrib.layers.sparse_column_with_hash_bucket(
      "native_country", hash_bucket_size=1000)

  # Continuous base columns.

  age = tf.contrib.layers.real_valued_column("age")
  education_num = tf.contrib.layers.real_valued_column("education_num")
  capital_gain = tf.contrib.layers.real_valued_column("capital_gain")
  capital_loss = tf.contrib.layers.real_valued_column("capital_loss")
  hours_per_week = tf.contrib.layers.real_valued_column("hours_per_week")

  # Transformations.
  age_buckets = tf.contrib.layers.bucketized_column(age,
                                                    boundaries=[
                                                        18, 25, 30, 35, 40, 45,
                                                        50, 55, 60, 65
                                                    ])

  # Wide columns and deep columns.
  wide_columns = [gender, native_country, education, occupation, workclass,
                  relationship, age_buckets,
                  tf.contrib.layers.crossed_column([education, occupation],
                                                   hash_bucket_size=int(1e4)),
                  tf.contrib.layers.crossed_column(
                      [age_buckets, education, occupation],
                      hash_bucket_size=int(1e6)),
                  tf.contrib.layers.crossed_column([native_country, occupation],
                                                   hash_bucket_size=int(1e4))]
  deep_columns = [
      tf.contrib.layers.embedding_column(workclass, dimension=8),
      tf.contrib.layers.embedding_column(education, dimension=8),
      tf.contrib.layers.embedding_column(gender, dimension=8),
      tf.contrib.layers.embedding_column(relationship, dimension=8),
      tf.contrib.layers.embedding_column(native_country,
                                         dimension=8),
      tf.contrib.layers.embedding_column(occupation, dimension=8),
      age,
      education_num,
      capital_gain,
      capital_loss,
      hours_per_week,
  ]

  if model_type == "wide":
    m = tf.contrib.learn.LinearClassifier(model_dir=model_dir,
                                          feature_columns=wide_columns)
  elif model_type == "deep":
    m = tf.contrib.learn.DNNClassifier(model_dir=model_dir,
                                       feature_columns=deep_columns,
                                       hidden_units=[100, 50])
  else:
    m = tf.contrib.learn.DNNLinearCombinedClassifier(
        model_dir=model_dir,
        linear_feature_columns=wide_columns,
        dnn_feature_columns=deep_columns,
        dnn_hidden_units=[100, 50])
  return m

# %% [markdown]
# ### Performing input data transformation to correspond to NN internal format

# %%
def input_fn(df):
  """Input builder function."""
  # Creates a dictionary mapping from each continuous feature column name (k) to
  # the values of that column stored in a constant Tensor.
  continuous_cols = {k: tf.constant(df[k].values) for k in CONTINUOUS_COLUMNS}
  # Creates a dictionary mapping from each categorical feature column name (k)
  # to the values of that column stored in a tf.SparseTensor.
  categorical_cols = {
      k: tf.SparseTensor(
          indices=[[i, 0] for i in range(df[k].size)],
          values=df[k].values,
          dense_shape=[df[k].size, 1])
      for k in CATEGORICAL_COLUMNS}
  # Merges the two dictionaries into one.
  feature_cols = dict(continuous_cols)
  feature_cols.update(categorical_cols)
  # Converts the label column into a constant Tensor.
  label = tf.constant(df[LABEL_COLUMN].values)
  # Returns the feature columns and the label.
  return feature_cols, label

# %%
### Performing training and evaluation

# %%
def train_and_eval(model_dir, model_type, train_steps, train_data, test_data):
  """Train and evaluate the model."""
  print("Model is training...")
  train_file_name, test_file_name = get_train_data_files(train_data, test_data)
  df_train = pd.read_csv(
      tf.gfile.Open(train_file_name),
      names=COLUMNS,
      skipinitialspace=True,
      engine="python")
  df_test = pd.read_csv(
      tf.gfile.Open(test_file_name),
      names=COLUMNS,
      skipinitialspace=True,
      skiprows=1,
      engine="python")

  # remove NaN elements
  df_train = df_train.dropna(how='any', axis=0)
  df_test = df_test.dropna(how='any', axis=0)

  df_train[LABEL_COLUMN] = (
      df_train["income_bracket"].apply(lambda x: ">50K" in x)).astype(int)
  df_test[LABEL_COLUMN] = (
      df_test["income_bracket"].apply(lambda x: ">50K" in x)).astype(int)

  df_train[LABEL_COLUMN] = (
      df_train["income_bracket"].apply(lambda x: ">50K" in x)).astype(int)
  df_test[LABEL_COLUMN] = (
      df_test["income_bracket"].apply(lambda x: ">50K" in x)).astype(int)
    
  model_dir = tempfile.mkdtemp() if not model_dir else model_dir
  print("model directory = %s" % model_dir)

  m = build_estimator(model_dir, model_type)
  m.fit(input_fn=lambda: input_fn(df_train), steps=train_steps)

  print("Model is evaluating...")

  results = m.evaluate(input_fn=lambda: input_fn(df_test), steps=1)
  print(df_test)
  for key in sorted(results):
    print("%s: %s" % (key, results[key]))

# %% [markdown]
# ### Main fuction (command line arguments parsing and calling train & evaluation)

# %%
FLAGS = None

def main(_):
  train_and_eval(FLAGS.model_dir, FLAGS.model_type, FLAGS.train_steps,
                 FLAGS.train_data, FLAGS.test_data)


if __name__ == "__main__":
  parser = argparse.ArgumentParser()
  parser.register("type", "bool", lambda v: v.lower() == "true")
  parser.add_argument(
      "--model_dir",
      type=str,
      default="",
      help="Base directory for output models."
  )
  parser.add_argument(
      "--model_type",
      type=str,
      default="wide_n_deep",
      help="Valid model types: {'wide', 'deep', 'wide_n_deep'}."
  )
  parser.add_argument(
      "--train_steps",
      type=int,
      default=200,
      help="Number of training steps."
  )
  parser.add_argument(
      "--train_data",
      type=str,
      default="",
      help="Path to the training data."
  )
  parser.add_argument(
      "--test_data",
      type=str,
      default="",
      help="Path to the test data."
  )
  FLAGS, unparsed = parser.parse_known_args()
  tf.app.run(main=main, argv=[sys.argv[0]] + unparsed)
  sys.exit()
# Out:
# Model is training...
# Training data is used from train_data.csv
# Test data is used from test_data.csv
# model directory = /tmp/tmpGV158h
# Model is evaluating...
#      age         workclass  fnlwgt     education  education_num  \
# NaN   25           Private  226802          11th              7
# NaN   38           Private   89814       HS-grad              9
# NaN   28         Local-gov  336951    Assoc-acdm             12
# NaN   44           Private  160323  Some-college             10
# NaN   18                 ?  103497  Some-college             10
# NaN   34           Private  198693          10th              6
# NaN   29                 ?  227026       HS-grad              9
# NaN   63  Self-emp-not-inc  104626   Prof-school             15
# NaN   24           Private  369667  Some-college             10
# NaN   55           Private  104996       7th-8th              4
# NaN   65           Private  184454       HS-grad              9
# NaN   36       Federal-gov  212465     Bachelors             13
# NaN   26           Private   82091       HS-grad              9
# NaN   58                 ?  299831       HS-grad              9
# NaN   48           Private  279724       HS-grad              9
# NaN   43           Private  346189       Masters             14
# NaN   20         State-gov  444554  Some-college             10
# NaN   43           Private  128354       HS-grad              9
# NaN   37           Private   60548       HS-grad              9
# NaN   40           Private   85019     Doctorate             16
# NaN   34           Private  107914     Bachelors             13
# NaN   34           Private  238588  Some-college             10
# NaN   72                 ?  132015       7th-8th              4
# NaN   25           Private  220931     Bachelors             13
# NaN   25           Private  205947     Bachelors             13
# NaN   45  Self-emp-not-inc  432824       HS-grad              9
# NaN   22           Private  236427       HS-grad              9
# NaN   23           Private  134446       HS-grad              9
# NaN   54           Private   99516       HS-grad              9
# NaN   32  Self-emp-not-inc  109282  Some-college             10
# ..   ...               ...     ...           ...            ...
# NaN   81                 ?   26711     Assoc-voc             11
# NaN   60           Private  117909     Assoc-voc             11
# NaN   39           Private  229647     Bachelors             13
# NaN   38           Private  149347       Masters             14
# NaN   43         Local-gov   23157       Masters             14
# NaN   23           Private   93977       HS-grad              9
# NaN   73      Self-emp-inc  159691  Some-college             10
# NaN   35           Private  176967  Some-college             10
# NaN   66           Private  344436       HS-grad              9
# NaN   27           Private  430340  Some-college             10
# NaN   40           Private  202168   Prof-school             15
# NaN   51           Private   82720       HS-grad              9
# NaN   22           Private  269623  Some-college             10
# NaN   64  Self-emp-not-inc  136405       HS-grad              9
# NaN   50         Local-gov  139347       Masters             14
# NaN   55           Private  224655       HS-grad              9
# NaN   38           Private  247547     Assoc-voc             11
# NaN   58           Private  292710    Assoc-acdm             12
# NaN   32           Private  173449       HS-grad              9
# NaN   48           Private  285570       HS-grad              9
# NaN   61           Private   89686       HS-grad              9
# NaN   31           Private  440129       HS-grad              9
# NaN   25           Private  350977       HS-grad              9
# NaN   48         Local-gov  349230       Masters             14
# NaN   33           Private  245211     Bachelors             13
# NaN   39           Private  215419     Bachelors             13
# NaN   64                 ?  321403       HS-grad              9
# NaN   38           Private  374983     Bachelors             13
# NaN   44           Private   83891     Bachelors             13
# NaN   35      Self-emp-inc  182148     Bachelors             13
#
#          marital_status         occupation    relationship  \
# NaN       Never-married  Machine-op-inspct       Own-child
# NaN  Married-civ-spouse    Farming-fishing         Husband
# NaN  Married-civ-spouse    Protective-serv         Husband
# NaN  Married-civ-spouse  Machine-op-inspct         Husband
# NaN       Never-married                  ?       Own-child
# NaN       Never-married      Other-service   Not-in-family
# NaN       Never-married                  ?       Unmarried
# NaN  Married-civ-spouse     Prof-specialty         Husband
# NaN       Never-married      Other-service       Unmarried
# NaN  Married-civ-spouse       Craft-repair         Husband
# NaN  Married-civ-spouse  Machine-op-inspct         Husband
# NaN  Married-civ-spouse       Adm-clerical         Husband
# NaN       Never-married       Adm-clerical   Not-in-family
# NaN  Married-civ-spouse                  ?         Husband
# NaN  Married-civ-spouse  Machine-op-inspct         Husband
# NaN  Married-civ-spouse    Exec-managerial         Husband
# NaN       Never-married      Other-service       Own-child
# NaN  Married-civ-spouse       Adm-clerical            Wife
# NaN             Widowed  Machine-op-inspct       Unmarried
# NaN  Married-civ-spouse     Prof-specialty         Husband
# NaN  Married-civ-spouse       Tech-support         Husband
# NaN       Never-married      Other-service       Own-child
# NaN            Divorced                  ?   Not-in-family
# NaN       Never-married     Prof-specialty   Not-in-family
# NaN  Married-civ-spouse     Prof-specialty         Husband
# NaN  Married-civ-spouse       Craft-repair         Husband
# NaN       Never-married       Adm-clerical       Own-child
# NaN           Separated  Machine-op-inspct       Unmarried
# NaN  Married-civ-spouse       Craft-repair         Husband
# NaN       Never-married     Prof-specialty   Not-in-family
# ..                  ...                ...             ...
# NaN  Married-civ-spouse                  ?         Husband
# NaN  Married-civ-spouse     Prof-specialty         Husband
# NaN       Never-married       Tech-support   Not-in-family
# NaN  Married-civ-spouse     Prof-specialty         Husband
# NaN  Married-civ-spouse    Exec-managerial         Husband
# NaN       Never-married  Machine-op-inspct       Own-child
# NaN            Divorced    Exec-managerial   Not-in-family
# NaN  Married-civ-spouse    Protective-serv         Husband
# NaN             Widowed              Sales  Other-relative
# NaN       Never-married              Sales   Not-in-family
# NaN  Married-civ-spouse     Prof-specialty         Husband
# NaN  Married-civ-spouse       Craft-repair         Husband
# NaN       Never-married       Craft-repair       Own-child
# NaN             Widowed    Farming-fishing   Not-in-family
# NaN  Married-civ-spouse     Prof-specialty            Wife
# NaN           Separated    Priv-house-serv   Not-in-family
# NaN       Never-married       Adm-clerical       Unmarried
# NaN            Divorced     Prof-specialty   Not-in-family
# NaN  Married-civ-spouse  Handlers-cleaners         Husband
# NaN  Married-civ-spouse       Adm-clerical         Husband
# NaN  Married-civ-spouse              Sales         Husband
# NaN  Married-civ-spouse       Craft-repair         Husband
# NaN       Never-married      Other-service       Own-child
# NaN            Divorced      Other-service   Not-in-family
# NaN       Never-married     Prof-specialty       Own-child
# NaN            Divorced     Prof-specialty   Not-in-family
# NaN             Widowed                  ?  Other-relative
# NaN  Married-civ-spouse     Prof-specialty         Husband
# NaN            Divorced       Adm-clerical       Own-child
# NaN  Married-civ-spouse    Exec-managerial         Husband
#
#                    race  gender  capital_gain  capital_loss  hours_per_week  \
# NaN               Black    Male             0             0              40
# NaN               White    Male             0             0              50
# NaN               White    Male             0             0              40
# NaN               Black    Male          7688             0              40
# NaN               White  Female             0             0              30
# NaN               White    Male             0             0              30
# NaN               Black    Male             0             0              40
# NaN               White    Male          3103             0              32
# NaN               White  Female             0             0              40
# NaN               White    Male             0             0              10
# NaN               White    Male          6418             0              40
# NaN               White    Male             0             0              40
# NaN               White  Female             0             0              39
# NaN               White    Male             0             0              35
# NaN               White    Male          3103             0              48
# NaN               White    Male             0             0              50
# NaN               White    Male             0             0              25
# NaN               White  Female             0             0              30
# NaN               White  Female             0             0              20
# NaN  Asian-Pac-Islander    Male             0             0              45
# NaN               White    Male             0             0              47
# NaN               Black  Female             0             0              35
# NaN               White  Female             0             0               6
# NaN               White    Male             0             0              43
# NaN               White    Male             0             0              40
# NaN               White    Male          7298             0              90
# NaN               White    Male             0             0              20
# NaN               Black    Male             0             0              54
# NaN               White    Male             0             0              35
# NaN               White    Male             0             0              60
# ..                  ...     ...           ...           ...             ...
# NaN               White    Male          2936             0              20
# NaN               White    Male          7688             0              40
# NaN               White  Female             0          1669              40
# NaN               White    Male             0             0              50
# NaN               White    Male             0          1902              50
# NaN               White    Male             0             0              40
# NaN               White  Female             0             0              40
# NaN               White    Male             0             0              40
# NaN               White  Female             0             0               8
# NaN               White  Female             0             0              45
# NaN               White    Male         15024             0              55
# NaN               White    Male             0             0              40
# NaN               White    Male             0             0              40
# NaN               White    Male             0             0              32
# NaN               White  Female             0             0              40
# NaN               White  Female             0             0              32
# NaN               Black  Female             0             0              40
# NaN               White    Male             0             0              36
# NaN               White    Male             0             0              40
# NaN               White    Male             0             0              40
# NaN               White    Male             0             0              48
# NaN               White    Male             0             0              40
# NaN               White  Female             0             0              40
# NaN               White    Male             0             0              40
# NaN               White    Male             0             0              40
# NaN               White  Female             0             0              36
# NaN               Black    Male             0             0              40
# NaN               White    Male             0             0              50
# NaN  Asian-Pac-Islander    Male          5455             0              40
# NaN               White    Male             0             0              60
#
#     native_country income_bracket  label
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States          >50K.      1
# NaN  United-States          >50K.      1
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States          >50K.      1
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States          >50K.      1
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States          >50K.      1
# NaN  United-States          >50K.      1
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN              ?          >50K.      1
# NaN  United-States          >50K.      1
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN           Peru         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States          >50K.      1
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# ..             ...            ...    ...
# NaN  United-States         <=50K.      0
# NaN  United-States          >50K.      1
# NaN  United-States         <=50K.      0
# NaN  United-States          >50K.      1
# NaN  United-States          >50K.      1
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States          >50K.      1
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN              ?          >50K.      1
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States         <=50K.      0
# NaN  United-States          >50K.      1
#
# [16281 rows x 16 columns]
# accuracy: 0.825564
# accuracy/baseline_label_mean: 0.236226
# accuracy/threshold_0.500000_mean: 0.825564
# auc: 0.868178
# global_step: 202
# labels/actual_label_mean: 0.236226
# labels/prediction_mean: 0.29874
# loss: 0.907977
# precision/positive_threshold_0.500000_mean: 0.641213
# recall/positive_threshold_0.500000_mean: 0.593864
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2889: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
